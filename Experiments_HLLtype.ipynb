# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from clawpack import pyclaw
from clawpack.visclaw.JSAnimation import IPython_display

# %%
from hydraulic_jump_2D import setup, plot_surface

# %%
claw = setup(h0=0.5, u0=0.75,riemann_solver='hllemcc',num_output_times=100,tfinal=20,num_cells=100,friction=True)
claw.run()
# Out:
# 2020-07-12 11:44:04,852 INFO CLAW: Solution 0 computed for time t=0.000000
# 2020-07-12 11:44:05,216 INFO CLAW: Solution 1 computed for time t=0.200000
# 2020-07-12 11:44:05,291 INFO CLAW: Solution 2 computed for time t=0.400000
# 2020-07-12 11:44:05,371 INFO CLAW: Solution 3 computed for time t=0.600000
# /home/dbatista/circular_hydraulic_jump_HLLtype/hydraulic_jump_2D.py:157: RuntimeWarning: invalid value encountered in subtract
#   q[2,:,:] = q[2,:,:] - dt*cf*v/h
# 2020-07-12 11:44:05,459 INFO CLAW: Solution 4 computed for time t=0.800000
# 2020-07-12 11:44:05,536 INFO CLAW: Solution 5 computed for time t=1.000000
# 2020-07-12 11:44:05,611 INFO CLAW: Solution 6 computed for time t=1.200000
# 2020-07-12 11:44:05,686 INFO CLAW: Solution 7 computed for time t=1.400000
# 2020-07-12 11:44:05,760 INFO CLAW: Solution 8 computed for time t=1.600000
# 2020-07-12 11:44:05,839 INFO CLAW: Solution 9 computed for time t=1.800000
# ...

# %%
anim=plot_surface(claw)
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# 2020-07-12 11:44:12,701 INFO CLAW: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2020-07-12 11:44:12,703 INFO CLAW: MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '720x720', '-pix_fmt', 'rgba', '-r', '25.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmpre_oe_8b/temp.m4v']
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
claw = setup(h0=0.5, u0=0.75,riemann_solver='hllemccroef',num_output_times=100,tfinal=20,num_cells=100,friction=True)
claw.run()
# Out:
# 2020-07-12 12:25:50,489 INFO CLAW: Solution 0 computed for time t=0.000000
# 2020-07-12 12:25:50,627 INFO CLAW: Solution 1 computed for time t=0.200000
# 2020-07-12 12:25:50,766 INFO CLAW: Solution 2 computed for time t=0.400000
# 2020-07-12 12:25:50,906 INFO CLAW: Solution 3 computed for time t=0.600000
# 2020-07-12 12:25:51,045 INFO CLAW: Solution 4 computed for time t=0.800000
# 2020-07-12 12:25:51,184 INFO CLAW: Solution 5 computed for time t=1.000000
# 2020-07-12 12:25:51,320 INFO CLAW: Solution 6 computed for time t=1.200000
# 2020-07-12 12:25:51,457 INFO CLAW: Solution 7 computed for time t=1.400000
# 2020-07-12 12:25:51,599 INFO CLAW: Solution 8 computed for time t=1.600000
# 2020-07-12 12:25:51,743 INFO CLAW: Solution 9 computed for time t=1.800000
# 2020-07-12 12:25:51,902 INFO CLAW: Solution 10 computed for time t=2.000000
# 2020-07-12 12:25:52,068 INFO CLAW: Solution 11 computed for time t=2.200000
# ...

# %%
anim=plot_surface(claw)
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# 2020-07-12 12:28:03,425 INFO CLAW: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2020-07-12 12:28:03,428 INFO CLAW: MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '720x720', '-pix_fmt', 'rgba', '-r', '25.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmpxkfx2907/temp.m4v']
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
claw = setup(h0=0.5, u0=0.75,riemann_solver='roe',num_output_times=100,tfinal=20,num_cells=100,friction=True)
claw.run()
# Out:
# 2020-07-12 12:28:19,233 INFO CLAW: Solution 0 computed for time t=0.000000
# 2020-07-12 12:28:19,350 INFO CLAW: Solution 1 computed for time t=0.200000
# 2020-07-12 12:28:19,463 INFO CLAW: Solution 2 computed for time t=0.400000
# 2020-07-12 12:28:19,576 INFO CLAW: Solution 3 computed for time t=0.600000
# 2020-07-12 12:28:19,689 INFO CLAW: Solution 4 computed for time t=0.800000
# 2020-07-12 12:28:19,805 INFO CLAW: Solution 5 computed for time t=1.000000
# 2020-07-12 12:28:19,929 INFO CLAW: Solution 6 computed for time t=1.200000
# 2020-07-12 12:28:20,102 INFO CLAW: Solution 7 computed for time t=1.400000
# 2020-07-12 12:28:20,269 INFO CLAW: Solution 8 computed for time t=1.600000
# 2020-07-12 12:28:20,408 INFO CLAW: Solution 9 computed for time t=1.800000
# 2020-07-12 12:28:20,521 INFO CLAW: Solution 10 computed for time t=2.000000
# 2020-07-12 12:28:20,633 INFO CLAW: Solution 11 computed for time t=2.200000
# ...

# %%
anim=plot_surface(claw)
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# 2020-07-12 12:29:08,682 INFO CLAW: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2020-07-12 12:29:08,683 INFO CLAW: MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '720x720', '-pix_fmt', 'rgba', '-r', '25.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmpfbu5phm1/temp.m4v']
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
claw = setup(h0=0.5, u0=0.75,riemann_solver='geoclaw',num_output_times=100,tfinal=20,num_cells=100,friction=True)
claw.run()
# Out:
# 2020-07-12 12:30:02,826 INFO CLAW: Solution 0 computed for time t=0.000000
# 2020-07-12 12:30:02,987 INFO CLAW: Solution 1 computed for time t=0.200000
# 2020-07-12 12:30:03,139 INFO CLAW: Solution 2 computed for time t=0.400000
# 2020-07-12 12:30:03,293 INFO CLAW: Solution 3 computed for time t=0.600000
# 2020-07-12 12:30:03,446 INFO CLAW: Solution 4 computed for time t=0.800000
# 2020-07-12 12:30:03,598 INFO CLAW: Solution 5 computed for time t=1.000000
# 2020-07-12 12:30:03,750 INFO CLAW: Solution 6 computed for time t=1.200000
# 2020-07-12 12:30:03,903 INFO CLAW: Solution 7 computed for time t=1.400000
# 2020-07-12 12:30:04,057 INFO CLAW: Solution 8 computed for time t=1.600000
# 2020-07-12 12:30:04,209 INFO CLAW: Solution 9 computed for time t=1.800000
# 2020-07-12 12:30:04,360 INFO CLAW: Solution 10 computed for time t=2.000000
# 2020-07-12 12:30:04,510 INFO CLAW: Solution 11 computed for time t=2.200000
# ...

# %%
anim=plot_surface(claw)
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# 2020-07-12 12:31:39,757 INFO CLAW: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2020-07-12 12:31:39,758 INFO CLAW: MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '720x720', '-pix_fmt', 'rgba', '-r', '25.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmpsin8zo0v/temp.m4v']
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
claw = setup(h0=0.5, u0=0.75,riemann_solver='hllemccroef',num_output_times=200,tfinal=20,num_cells=200,friction=True)
claw.run()
# Out:
# 2020-07-12 12:36:37,041 INFO CLAW: Solution 0 computed for time t=0.000000
# 2020-07-12 12:36:37,484 INFO CLAW: Solution 1 computed for time t=0.100000
# 2020-07-12 12:36:37,961 INFO CLAW: Solution 2 computed for time t=0.200000
# 2020-07-12 12:36:38,499 INFO CLAW: Solution 3 computed for time t=0.300000
# 2020-07-12 12:36:39,014 INFO CLAW: Solution 4 computed for time t=0.400000
# 2020-07-12 12:36:39,543 INFO CLAW: Solution 5 computed for time t=0.500000
# 2020-07-12 12:36:40,056 INFO CLAW: Solution 6 computed for time t=0.600000
# 2020-07-12 12:36:40,562 INFO CLAW: Solution 7 computed for time t=0.700000
# 2020-07-12 12:36:41,087 INFO CLAW: Solution 8 computed for time t=0.800000
# 2020-07-12 12:36:41,593 INFO CLAW: Solution 9 computed for time t=0.900000
# 2020-07-12 12:36:42,125 INFO CLAW: Solution 10 computed for time t=1.000000
# 2020-07-12 12:36:42,640 INFO CLAW: Solution 11 computed for time t=1.100000
# ...

# %%
anim=plot_surface(claw)
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# 2020-07-12 12:39:07,523 INFO CLAW: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2020-07-12 12:39:07,524 INFO CLAW: MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '720x720', '-pix_fmt', 'rgba', '-r', '25.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmpl4sj4qw4/temp.m4v']
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
claw = setup(h0=0.5, u0=0.75,riemann_solver='roe',num_output_times=200,tfinal=20,num_cells=200,friction=True)
claw.run()
# Out:
# 2020-07-12 12:39:22,600 INFO CLAW: Solution 0 computed for time t=0.000000
# 2020-07-12 12:39:23,019 INFO CLAW: Solution 1 computed for time t=0.100000
# 2020-07-12 12:39:23,434 INFO CLAW: Solution 2 computed for time t=0.200000
# 2020-07-12 12:39:23,909 INFO CLAW: Solution 3 computed for time t=0.300000
# 2020-07-12 12:39:24,330 INFO CLAW: Solution 4 computed for time t=0.400000
# 2020-07-12 12:39:24,806 INFO CLAW: Solution 5 computed for time t=0.500000
# 2020-07-12 12:39:25,218 INFO CLAW: Solution 6 computed for time t=0.600000
# 2020-07-12 12:39:25,650 INFO CLAW: Solution 7 computed for time t=0.700000
# 2020-07-12 12:39:26,071 INFO CLAW: Solution 8 computed for time t=0.800000
# 2020-07-12 12:39:26,493 INFO CLAW: Solution 9 computed for time t=0.900000
# 2020-07-12 12:39:26,920 INFO CLAW: Solution 10 computed for time t=1.000000
# 2020-07-12 12:39:27,329 INFO CLAW: Solution 11 computed for time t=1.100000
# ...

# %%
anim=plot_surface(claw)
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# 2020-07-12 12:42:15,563 INFO CLAW: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2020-07-12 12:42:15,565 INFO CLAW: MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '720x720', '-pix_fmt', 'rgba', '-r', '25.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmp74_s4czo/temp.m4v']
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...
